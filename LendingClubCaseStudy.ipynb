# %% [markdown]
# # Lending Club Case Study

# %% [markdown]
# Lending Club- a a finance company that provides various loans to the customers.When the company receives a loan application, the company has to make a decision for loan approval based on the applicant’s profile. Two types of risks are associated with the bank’s decision:
#
# * If the applicant is likely to repay the loan, then not approving the loan results in a loss of business to the company
#
# * If the applicant is not likely to repay the loan, i.e. he/she is likely to default, then approving the loan may lead to a financial loss for the company
#
#
# The data given below contains the information about past loan applicants from the time period 2007 to 2011. and whether they ‘defaulted’ or not. The aim is to identify patterns which indicate if a person is likely to default, which may be used for taking actions such as denying the loan, reducing the amount of loan, lending (to risky applicants) at a higher interest rate, etc.
#
# So the aim is to find out the patternes on which the finance company will bear the loan amount or avoide to fund the amount that indicates the risk behind it.

# %% [markdown]
# When a person applies for a loan, there are two types of decisions that could be taken by the company:
#
# 1) **Loan accepted**: If the company approves the loan, there are 3 possible scenarios described below:
#
# * Fully paid: Applicant has fully paid the loan (the principal and the interest rate)
#
# * Current: Applicant is in the process of paying the instalments, i.e. the tenure of the loan is not yet completed. These candidates are not labelled as 'defaulted'.
#
# * Charged-off: Applicant has not paid the instalments in due time for a long period of time, i.e. he/she has defaulted on the loan
#
# 2) **Loan rejected**: The company had rejected the loan (because the candidate does not meet their requirements etc.). Since the loan was rejected, there is no transactional history of those applicants with the company and so this data is not available with the company (and thus in this dataset)

# %% [markdown]
# ## Problem Statement:
#
# To understand the driving factors (or driver variables) behind loan default, i.e. the variables which are strong indicators of default.  The company can utilise this knowledge for its portfolio and risk assessment.

# %% [markdown]
# ## Business Objective
#
# 1. Data Cleaning
# 2. Exploratory Data Analysis
# 3. Trying to provide some interpretability and evolving our ways to handle the upcoming problems as we proceed through our case study

# %% [markdown]
# ## Data Description
#
# * `id` - 	A unique LC assigned ID for the loan listing.
# * `member_id` - 	A unique LC assigned Id for the borrower member.
# * `loan_amnt` - 	The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
# * `funded_amnt` - 	The total amount committed to that loan at that point in time.
# * `funded_amnt_inv` - 	The total amount committed by investors for that loan at that point in time.
# * `term` - 	The number of payments on the loan. Values are in months and can be either 36 or 60.
# * `int_rate` - 	Interest Rate on the loan
# * `installment` - 	The monthly payment owed by the borrower if the loan originates.
# * `grade` - 	LC assigned loan grade
# * `sub_grade` - 	LC assigned loan subgrade
# * `emp_title` - 	The job title supplied by the Borrower when applying for the loan.*
# * `emp_length` - 	Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
# * `home_ownership` - 	The home ownership status provided by the borrower during registration. Our values are: RENT, OWN, MORTGAGE, OTHER.
# * `annual_inc` - 	The self-reported annual income provided by the borrower during registration.
# * `verification_status` - 	Indicates if income was verified by LC, not verified, or if the income source was verified
# * `issue_d` - 	The month which the loan was funded
# * `loan_status` - 	Current status of the loan
# * `pymnt_plan` - 	Indicates if a payment plan has been put in place for the loan
# * `url` - 	URL for the LC page with listing data.
# * `desc` - 	Loan description provided by the borrower
# * `purpose` - 	A category provided by the borrower for the loan request.
# * `title` - 	The loan title provided by the borrower
# * `zip_code` - 	The first 3 numbers of the zip code provided by the borrower in the loan application.
# * `addr_state` - 	The state provided by the borrower in the loan application
# * `dti` - 	A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.
# * `delinq_2yrs` - 	The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years
# * `earliest_cr_line` - 	The month the borrower's earliest reported credit line was opened
# * `inq_last_6mths` - 	The number of inquiries in past 6 months (excluding auto and mortgage inquiries)
# * `mths_since_last_delinq` - 	The number of months since the borrower's last delinquency.
# * `mths_since_last_record` - 	The number of months since the last public record.
# * `open_acc` - 	The number of open credit lines in the borrower's credit file.
# * `pub_rec` - 	Number of derogatory public records
# * `revol_bal` - 	Total credit revolving balance
# * `revol_util` - 	Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
# * `total_acc` - 	The total number of credit lines currently in the borrower's credit file
# * `initial_list_status` - 	The initial listing status of the loan. Possible values are – W, F
# * `out_prncp` - 	Remaining outstanding principal for total amount funded
# * `out_prncp_inv` - 	Remaining outstanding principal for portion of total amount funded by investors
# * `total_pymnt` - 	Payments received to date for total amount funded
# * `total_pymnt_inv` - 	Payments received to date for portion of total amount funded by investors
# * `total_rec_prncp` - 	Principal received to date
# * `total_rec_int` - 	Interest received to date
# * `total_rec_late_fee` - 	Late fees received to date
# * `recoveries` - 	post charge off gross recovery
# * `collection_recovery_fee` - 	post charge off collection fee
# * `last_pymnt_d` - 	Last month payment was received
# * `last_pymnt_amnt` - 	Last total payment amount received
# * `next_pymnt_d` - 	Next scheduled payment date
# * `last_credit_pull_d` - 	The most recent month LC pulled credit for this loan
# * `collections_12_mths_ex_med` - 	Number of collections in 12 months excluding medical collections
# * `mths_since_last_major_derog` - 	Months since most recent 90-day or worse rating
# * `policy_code` - 	"publicly available policy_code=1
# new products not publicly available policy_code=2"
# * `application_type` - 	Indicates whether the loan is an individual application or a joint application with two co-borrowers
# * `annual_inc_joint` - 	The combined self-reported annual income provided by the co-borrowers during registration
# * `dti_joint` - 	A ratio calculated using the co-borrowers' total monthly payments on the total debt obligations, excluding mortgages and the requested LC loan, divided by the co-borrowers' combined self-reported monthly income
# * `verification_status_joint` - 	Indicates if income was verified by LC, not verified, or if the income source was verified
# * `acc_now_delinq` - 	The number of accounts on which the borrower is now delinquent.
# * `tot_coll_amt` - 	Total collection amounts ever owed
# * `tot_cur_bal` - 	Total current balance of all accounts
# * `open_acc_6m` - 	Number of open trades in last 6 months
# * `open_il_6m` - 	Number of currently active installment trades
# * `open_il_12m` - 	Number of installment accounts opened in past 12 months
# * `open_il_24m` - 	Number of installment accounts opened in past 24 months
# * `mths_since_rcnt_il` - 	Months since most recent installment accounts opened
# * `total_bal_il` - 	Total current balance of all installment accounts
# * `il_util` - 	Ratio of total current balance to high credit/credit limit on all install acct
# * `open_rv_12m` - 	Number of revolving trades opened in past 12 months
# * `open_rv_24m` - 	Number of revolving trades opened in past 24 months
# * `max_bal_bc` - 	Maximum current balance owed on all revolving accounts
# * `all_util` - 	Balance to credit limit on all trades
# * `total_rev_hi_lim` - 	Principal received to date
# * `inq_fi` - 	Number of personal finance inquiries
# * `total_cu_tl` - 	Number of finance trades
# * `inq_last_12m` - 	Number of credit inquiries in past 12 months
# * `acc_open_past_24mths` - 	Number of trades opened in past 24 months.
# * `avg_cur_bal` - 	Average current balance of all accounts
# * `bc_open_to_buy` - 	Total open to buy on revolving bankcards.
# * `bc_util` - 	Ratio of total current balance to high credit/credit limit for all bankcard accounts.
# * `chargeoff_within_12_mths` - 	Number of charge-offs within 12 months
# * `delinq_amnt` - 	The past-due amount owed for the accounts on which the borrower is now delinquent.
# * `mo_sin_old_il_acct` - 	Months since oldest bank installment account opened
# * `mo_sin_old_rev_tl_op` - 	Months since oldest revolving account opened
# * `mo_sin_rcnt_rev_tl_op` - 	Months since most recent revolving account opened
# * `mo_sin_rcnt_tl` - 	Months since most recent account opened
# * `mort_acc` - 	Number of mortgage accounts.
# * `mths_since_recent_bc` - 	Months since most recent bankcard account opened.
# * `mths_since_recent_bc_dlq` - 	Months since most recent bankcard delinquency
# * `mths_since_recent_inq` - 	Months since most recent inquiry.
# * `mths_since_recent_revol_delinq` - 	Months since most recent revolving delinquency.
# * `num_accts_ever_120_pd` - 	Number of accounts ever 120 or more days past due
# * `num_actv_bc_tl` - 	Number of currently active bankcard accounts
# * `num_actv_rev_tl` - 	Number of currently active revolving trades
# * `num_bc_sats` - 	Number of satisfactory bankcard accounts
# * `num_bc_tl` - 	Number of bankcard accounts
# * `num_il_tl` - 	Number of installment accounts
# * `num_op_rev_tl` - 	Number of open revolving accounts
# * `num_rev_accts` - 	Number of revolving accounts
# * `num_rev_tl_bal_gt_0` - 	Number of revolving trades with balance >0
# * `num_sats` - 	Number of satisfactory accounts
# * `num_tl_120dpd_2m` - 	Number of accounts currently 120 days past due (updated in past 2 months)
# * `num_tl_30dpd` - 	Number of accounts currently 30 days past due (updated in past 2 months)
# * `num_tl_90g_dpd_24m` - 	Number of accounts 90 or more days past due in last 24 months
# * `num_tl_op_past_12m` - 	Number of accounts opened in past 12 months
# * `pct_tl_nvr_dlq` - 	Percent of trades never delinquent
# * `percent_bc_gt_75` - 	Percentage of all bankcard accounts > 75% of limit.
# * `pub_rec_bankruptcies` - 	Number of public record bankruptcies
# * `tax_liens` - 	Number of tax liens
# * `tot_hi_cred_lim` - 	Total high credit/credit limit
# * `total_bal_ex_mort` - 	Total credit balance excluding mortgage
# * `total_bc_limit` - 	Total bankcard high credit/credit limit
# * `total_il_high_credit_limit` - 	Total installment high credit/credit limit
#
# According to our case study we can say that,
#
# **Target Variable:** `loan_status`

# %% [markdown]
# ## Step 1 - Data Cleaning
#
# * The very first step in solving any case study in data science is to properly look and analyze the data you have.
# * Basic data cleaning steps are removal of null values, null values imputation and outlier detection.

# %% [markdown]
# #### Importing the libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Loading the data

# %%
data = pd.read_csv("loan.csv", low_memory= False)
data.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0   10.65%       162.87     B        B2                       NaN  10+ years
# 1   15.27%        59.83     C        C4                     Ryder   < 1 year
# 2   15.96%        84.33     C        C5                       NaN  10+ years
# 3   13.49%       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4   12.69%        67.79     B        B5  University Medical Group     1 year
#
# ...

# %%
# printing the size of the data
print(data.shape)
# Out:
# (39717, 111)

# %% [markdown]
# This shows us that we have **39717** records with **111** columns

# %%
# we don't know that whether the applicant with loan status as current can be considered as defaulter and non defaulter.
# Therefore, we cannot consider it and can delete it from data.
data = data[data['loan_status'] != 'Current']
print(data.shape)
# Out:
# (38577, 111)

# %% [markdown]
# This shows us that we have **38577** records with **111** columns
#
# After observing data.head() we can see that there are many columns which are having null values which can be dropped as it is not containing any data.

# %%
# Dropped the columns whose all the values are null values
data.dropna(axis=1,how='all',inplace=True)
# Checking the shape of the data
print(data.shape)
# Out:
# (38577, 56)

# %% [markdown]
# After that dropping the columns we can see that we have **38577** records and **56** columns to work with.

# %%
# deleting id and member_id as it is not significant variable since, it is just a number to identify the person.
data.drop(['id','member_id'],axis = 1,inplace = True)
# checking whether the id and member_id column is deleted or not
print('id' in data.columns and 'member_id' in data.columns)
# Out:
# False

# %% [markdown]
# We can see that column names - `id` & `member_id` has been deleted.

# %%
# deleting issue date as it will make no sense before loan application since it is the issue date of loan 
del data['issue_d']
# checking whether the issue_d column is deleted or not
print('issue_d' in data.columns)
# Out:
# False

# %% [markdown]
# We can see that column name - `issue_d` has been deleted.

# %%
# Deleting 'pymnt_plan' columns - insignificant variable as all the values are same.
del data['pymnt_plan']
# checking whether the  column is deleted or not
print('pymnt_plan' in data.columns)
# Out:
# False

# %% [markdown]
# We can see that column name - `pymnt_plan` has been deleted.

# %%
# We can delete the column 'url' as it cannot be accessed and we connot scrap any new data from it.
# Therefore, deleting 'url' column
del data['url']
# checking whether the 'url' column is deleted or not
print('url' in data.columns)
# Out:
# False

# %% [markdown]
# We can see that column name - `url` has been deleted.

# %%
# We can delete the 'description' and 'title' as the data contains a column name 'purpose' which is similar to both
data.drop(['desc','title'],axis = 1,inplace=True)
# checking whether the  column is deleted or not
print('desc' in data.columns and 'title' in data.columns)
# Out:
# False

# %% [markdown]
# We can see that column name - `title` has been deleted.

# %%
# 'Zipcode' can't define whether the applicant is defaulter or not.
del data['zip_code']
# checking whether the 'zipcode' column is deleted or not
print('zip_code' in data.columns)
# Out:
# False

# %% [markdown]
# We can see that column name - `zip_code` has been deleted.

# %%
# Deleting 'initial_list_status' columns - insignificant variable as all the values are same.
del data['initial_list_status']
# checking whether the  column is deleted or not
print('initial_list_status' in data.columns)
# Out:
# False

# %% [markdown]
# We can see that column name - `initial_list_status` has been deleted.

# %%
# Deleting all details of payment which was regarding repayment after loan was accepted. And our moto is to find whether the
# given data of applicant can be defaulter or not before loan approval.
# ['out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv','total_rec_prncp',
# 'total_rec_int','total_rec_late_fee','recoveries','collection_recovery_fee',
# 'last_pymnt_d','last_pymnt_amnt','last_credit_pull_d','collections_12_mths_ex_med']

data.drop(['out_prncp','out_prncp_inv','total_pymnt','total_pymnt_inv','total_rec_prncp',
           'total_rec_int','total_rec_late_fee','recoveries','collection_recovery_fee',
           'last_pymnt_d','last_pymnt_amnt','last_credit_pull_d','collections_12_mths_ex_med'],axis = 1,inplace=True)

# %%
# Deleting below columns as they are indicating same records in their respective columns.
# ['policy_code','application_type','acc_now_delinq','delinq_amnt']

# and also deleting chargeoff_within_12_mths and tax_liens as it contains same values and less null value.
# Therefore, if we impute the value of null value to median then all rows will have same values.
# ['chargeoff_within_12_mths','tax_liens']

data.drop(['policy_code','application_type','acc_now_delinq','delinq_amnt','chargeoff_within_12_mths','tax_liens'],axis = 1,inplace=True)

# %% [markdown]
# Printing the size of the data -

# %%
print(data.shape)
# Out:
# (38577, 28)

# %% [markdown]
# ##### After deleting all unwanted columns now we can check the data and change the data types of columns according to their siginificance.

# %%
# printing all the datatype of data for better understanding
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38577 entries, 0 to 39716
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   loan_amnt               38577 non-null  int64
#  1   funded_amnt             38577 non-null  int64
#  2   funded_amnt_inv         38577 non-null  float64
#  3   term                    38577 non-null  object
#  4   int_rate                38577 non-null  object
#  5   installment             38577 non-null  float64
#  6   grade                   38577 non-null  object
#  7   sub_grade               38577 non-null  object
#  8   emp_title               36191 non-null  object
#  9   emp_length              37544 non-null  object
#  10  home_ownership          38577 non-null  object
#  11  annual_inc              38577 non-null  float64
#  12  verification_status     38577 non-null  object
#  13  loan_status             38577 non-null  object
# ...

# %%
# interest rate should be numeric as it is rate of interest of loan that cannot be object
# As it is in percentage that means we have to convert it to numeric
# revol_util is also represented in percentage which means it has to be converted to numeric.
data['int_rate'] = data['int_rate'].apply(lambda x : float(x.strip('%')))
data['revol_util'] = data['revol_util'].apply(lambda x : float(str(x).strip('%')))
# checking whether the above changes has been done in our data or not.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38577 entries, 0 to 39716
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   loan_amnt               38577 non-null  int64
#  1   funded_amnt             38577 non-null  int64
#  2   funded_amnt_inv         38577 non-null  float64
#  3   term                    38577 non-null  object
#  4   int_rate                38577 non-null  float64
#  5   installment             38577 non-null  float64
#  6   grade                   38577 non-null  object
#  7   sub_grade               38577 non-null  object
#  8   emp_title               36191 non-null  object
#  9   emp_length              37544 non-null  object
#  10  home_ownership          38577 non-null  object
#  11  annual_inc              38577 non-null  float64
#  12  verification_status     38577 non-null  object
#  13  loan_status             38577 non-null  object
# ...

# %% [markdown]
# ### Using EDA for data cleaning

# %%
# checking for correlation in the data.
corr = data.corr()
plt.figure(figsize=(20,12))
sns.heatmap(corr,annot=True,cmap='Greens')
plt.show()

# %%
# deleting funded_amnt, funded_amnt_inv and installment as it correlated to loan amount
data.drop(['funded_amnt','funded_amnt_inv','installment'],axis = 1,inplace=True)

# %%
# deleting pub_rec_bankruptcies as it is correlated to pub_rec and pub_rec is showing the number of derogatory public records.
# It means that if applicant is in record of pub_rec_bankruptcies then they will have bad derogatory record.
# Therefore we can delete pub_rec_bankruptcies
data.drop(['pub_rec_bankruptcies'],axis = 1,inplace=True)

# %%
# after deleting the columns checking whether the plot is changed or not
corr = data.corr()
plt.figure(figsize=(20,12))
sns.heatmap(corr,annot=True,cmap='Greens')
plt.show()

# %%
# Printing the % of null values in all columns
print(data.isna().sum()/len(data)*100)
# Out:
# loan_amnt                  0.000000
# term                       0.000000
# int_rate                   0.000000
# grade                      0.000000
# sub_grade                  0.000000
# emp_title                  6.185033
# emp_length                 2.677761
# home_ownership             0.000000
# annual_inc                 0.000000
# verification_status        0.000000
# loan_status                0.000000
# purpose                    0.000000
# addr_state                 0.000000
# dti                        0.000000
# delinq_2yrs                0.000000
# earliest_cr_line           0.000000
# inq_last_6mths             0.000000
# mths_since_last_delinq    64.559193
# mths_since_last_record    92.897322
# open_acc                   0.000000
# pub_rec                    0.000000
# revol_bal                  0.000000
# revol_util                 0.129611
# total_acc                  0.000000
# dtype: float64

# %% [markdown]
# As we can see that mths_since_last_record columns is having around 93% of null values and also it is correlated to pub_rec. Therefore, it can be deleted.
# Also, we can delete mths_since_last_delinq as it has around 64% are null values.

# %%
# deleting mths_since_last_record and mths_since_last_delinq
data.drop(['mths_since_last_record','mths_since_last_delinq'],axis = 1,inplace=True)

# %% [markdown]
# We cannot replace the null values as it can over exaggerate the data and it can create biasness in the data.So it is better to not treat the null values.

# %%
# after deleting the columns checking whether the plot is changed or not
corr = data.corr()
plt.figure(figsize=(20,12))
sns.heatmap(corr,annot=True,cmap='Greens')
plt.show()

# %% [markdown]
# ##### Dealing with Null Values

# %% [markdown]
# Going through data, now we know that rows cannot be deleted as the maximum null values in a row is not more than 50%.

# %%
# printing sum of null values column wise to check how many columns are having null values and its values.
print(data.isna().sum())
# Out:
# loan_amnt                 0
# term                      0
# int_rate                  0
# grade                     0
# sub_grade                 0
# emp_title              2386
# emp_length             1033
# home_ownership            0
# annual_inc                0
# verification_status       0
# loan_status               0
# purpose                   0
# addr_state                0
# dti                       0
# delinq_2yrs               0
# earliest_cr_line          0
# inq_last_6mths            0
# open_acc                  0
# pub_rec                   0
# revol_bal                 0
# revol_util               50
# total_acc                 0
# dtype: int64

# %% [markdown]
# We can see that 3 columns are having null values and we know if it is categorical data then we have to replace the null values with mode and if it is a numeric data then we have to replace the null values with mean or median.
#
# But in our case we can replace the numeric data as the missing value percentage is very low and it will not overexaggerate the data. but in case of columns like `emp_title` and `emp_length` we can't as it will over exaggerate the data and will give us bias to some records. It is better to replace it with Unknown or leave as it is. In our case we are replacing the null values with 'Unknown' in categorical columns

# %%
cols  = ['emp_title','emp_length','revol_util']
for col in cols:
    if data[col].dtype == 'O':
        data[col].fillna("Unknown",inplace = True)
    if data[col].dtype == 'float64' or data[col].dtype == 'int64':
        data[col].fillna((data[col].median()),inplace = True)

# %%
# checking whether the above changes is done or not.
print(data.isna().sum())
# Out:
# loan_amnt              0
# term                   0
# int_rate               0
# grade                  0
# sub_grade              0
# emp_title              0
# emp_length             0
# home_ownership         0
# annual_inc             0
# verification_status    0
# loan_status            0
# purpose                0
# addr_state             0
# dti                    0
# delinq_2yrs            0
# earliest_cr_line       0
# inq_last_6mths         0
# open_acc               0
# pub_rec                0
# revol_bal              0
# revol_util             0
# total_acc              0
# dtype: int64

# %% [markdown]
# Now, there are no null values left in the data so we can go ahead with the outlier treatment.

# %%
# checking for outlier in annual income
plt.figure(figsize=(8,8))
data['annual_inc'].plot(kind = 'box')
plt.show()
print(data['annual_inc'].describe([0,0.25,0.5,0.75,0.95,1]))
# Out:
# count    3.857700e+04
# mean     6.877797e+04
# std      6.421868e+04
# min      4.000000e+03
# 0%       4.000000e+03
# 25%      4.000000e+04
# 50%      5.886800e+04
# 75%      8.200000e+04
# 95%      1.400040e+05
# 100%     6.000000e+06
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %% [markdown]
# It is seen that there are a lot of outliers in `annual_inc`(annual income) column, so we can try to remove some records as it is too far from the median and they are creating variation in data.

# %%
# We are keeping the value till 95 percentile as we are not losing much data and quality of data is also retained.
cut_off = data['annual_inc'].quantile(0.95)
data = data[data['annual_inc'] <= cut_off]
plt.figure(figsize=(8,8))
data['annual_inc'].plot(kind = 'box')
plt.show()
print(data['annual_inc'].describe())
# Out:
# count     36654.000000
# mean      60855.751621
# std       27750.284125
# min        4000.000000
# 25%       40000.000000
# 50%       56000.000000
# 75%       77970.500000
# max      140004.000000
# Name: annual_inc, dtype: float64

# %% [markdown]
# We can see that after removing 5 percentile of data, extreme outlier has been treated properly.

# %%
# Checking for outlier in loan_amnt column
plt.figure(figsize = (8,8))
data['loan_amnt'].plot(kind='box')
plt.show()
print(data['loan_amnt'].describe())
# Out:
# count    36654.000000
# mean     10682.249550
# std       7048.414166
# min        500.000000
# 25%       5000.000000
# 50%       9250.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %% [markdown]
# We can see that the upper whisker is close to maximum value, so it is better to keep the data as it is.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36654 entries, 0 to 39716
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   loan_amnt            36654 non-null  int64
#  1   term                 36654 non-null  object
#  2   int_rate             36654 non-null  float64
#  3   grade                36654 non-null  object
#  4   sub_grade            36654 non-null  object
#  5   emp_title            36654 non-null  object
#  6   emp_length           36654 non-null  object
#  7   home_ownership       36654 non-null  object
#  8   annual_inc           36654 non-null  float64
#  9   verification_status  36654 non-null  object
#  10  loan_status          36654 non-null  object
#  11  purpose              36654 non-null  object
#  12  addr_state           36654 non-null  object
#  13  dti                  36654 non-null  float64
#  14  delinq_2yrs          36654 non-null  int64
# ...

# %% [markdown]
# ## Step 2  - Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ##### Pie-chart on target variable

# %%
# Plotting a pie chart of Loan status to see the distribution of the data.
plt.figure(figsize=(12,8))
data['loan_status'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# We can say that data consists of non defaulter(**Fully Paid**) more than defaulter(**Charged Off**).

# %% [markdown]
# ##### Analysis on Loan Amount

# %%
sns.distplot(data.loan_amnt,kde = False)
plt.xlabel("Loan Amount")
plt.title("Loan Amount Analysis")
plt.show()

# %% [markdown]
# We can say that most of the applicant are applying for loan amount less than 15000.

# %% [markdown]
# ##### Analysis on Interest rate

# %%
sns.distplot(data.int_rate)
plt.xlabel("Interest rate")
plt.title("Interest rate Analysis")
plt.show()

# %% [markdown]
# From graph, we can see that most of the applicants were given loan with a interest rate from 10% to 13%.

# %% [markdown]
# ##### Analysis on dti

# %%
sns.distplot(data.dti,kde = False)
plt.xlabel("DTI")
plt.title("DTI Analysis")
plt.show()

# %% [markdown]
# From graph, we can see that most of the applicant has DTI of 15 which can be more analysed in bivariate as it cannot interpret whether it is affecting the loan status or not.

# %% [markdown]
# ##### Analysis on Verification of Income

# %%
# Plotting a countplot for Verification of status
data.verification_status.value_counts().plot(kind = 'bar')
plt.title("Verification Status")
plt.show()

# %% [markdown]
# We can say that the verification of income was not done more often.

# %% [markdown]
# ##### Analysis on Annual Income

# %%
# bucketing the income column for better Analysis
bins = [0,25000,50000,75000,100000,125000,np.inf]
labels = ['0-25k','25k-50k','50k-75k','75k-100k','100k-125k','>125k']
data['Annual Income Slab'] = pd.cut(data['annual_inc'],bins=bins,labels= labels)

# %%
# ploting the countplot
sns.countplot(data['Annual Income Slab'])
plt.ylabel("Frequency")
plt.title("Annual Income Analysis")
plt.show()

# %% [markdown]
# From above graph, We can see that the applicant with low income has applied less no. of loans compared to income slab of 100k to 125k. And also, we can see that most applicant has a income range of 25k to 50k and it decreases thereafter.

# %% [markdown]
# ##### Analyis on Loan Tenure

# %%
# plotting countplot
sns.countplot(data['term'])
plt.xlabel("Loan Tenure")
plt.ylabel("Frequency")
plt.title("Loan Term Analysis")
plt.show()

# %% [markdown]
# From the graph, We can see that most of the applicant are going for less no. of loan tenure.

# %% [markdown]
# As we can see that univariate analysis is good but it is not showing us the proper insights with respect to others variables. Therefore, We will do some bi-variate analysis to get better insights.

# %% [markdown]
# ### Bi-variate Analysis

# %% [markdown]
# ##### Loan amount vs Loan Status

# %%
sns.barplot(data = data,x ='loan_status',y = 'loan_amnt',estimator = np.median)
plt.xlabel("Loan Status")
plt.ylabel("Loan Amount")
plt.title("Loan Status vs Loan Amount")
plt.show()

# %% [markdown]
# From tha graph, we can see that the median value of charged off is greater than fully paid customer. Therefore, we can say that whenever applicant is asking for more loan we should scrutinize them more cautiously compared to others. **It can be a good driving variable.**

# %% [markdown]
# ##### Analysis wrt Interest rate and Loan Status

# %%
sns.boxplot(data['loan_status'],data['int_rate'])
plt.xlabel('Loan Status')
plt.ylabel('Interest Rate')
plt.title('Interest rate vs Loan status')
plt.show()
# Out:
# Text(0.5, 1.0, 'Interest rate vs Loan status')

# %% [markdown]
# From boxplot, we can interpret that if the interest rate is high then the possibility of applicant becoming defaulter is high. **It can be good driving variable**.

# %% [markdown]
# ##### According to Grade

# %%
data_1 = data[['grade','loan_status']].value_counts().unstack()
data_1_perc = data_1.apply(lambda x : x/x.sum(),axis=1)

figure, (ax1,ax2) = plt.subplots(1, 2,figsize = (10,5))
data_1.plot(kind = 'bar',stacked = True,ax = ax1)
data_1_perc.plot(kind = 'bar',stacked = True,ax = ax2)
plt.show()

# %% [markdown]
# From both the graph we can say that the grade is a **good indicator** to identify that whether the given applicant will be defaulter or not. We can see that as the grade is getting lower the percentage of applicant being defaulter is more.

# %% [markdown]
# ###### Analysis on Grade and interest rate

# %%
plt.figure(figsize = (8,5))
sns.boxplot(data['grade'],data['int_rate'])
plt.xlabel('Grade')
plt.ylabel('Interest rate')
plt.title('Interest rate vs Grade')
plt.show()

# %% [markdown]
# From the graph, we can say that the applicant with grade 'G' gets a loan on high interest rate than others and that could be the reason that those applicants are getting more defaulted than others. We can try to dig deep into knowing better with help of sub-grade columns.

# %% [markdown]
# ##### Analysis on Sub-grade

# %%
data_1 = data[['sub_grade','loan_status']].value_counts().unstack()
data_1_perc = data_1.apply(lambda x : x/x.sum(),axis=1)

figure, (ax1,ax2) = plt.subplots(1, 2,figsize = (20,5))
data_1.plot(kind = 'bar',stacked = True,ax = ax1)
data_1_perc.plot(kind = 'bar',stacked = True,ax = ax2)
plt.show()

# %% [markdown]
# From graphs, we can see that applicant with sub-grade of **'F5'** is prone to be a defaulter compare to other sub grades. we can try to analyze the same with different plots.

# %% [markdown]
# ###### Analysis on Sub-Grade and interest rate

# %%
plt.figure(figsize = (20,5))
sns.boxplot(data['sub_grade'],data['int_rate'])
plt.xlabel('Sub Grade')
plt.ylabel('Interest rate')
plt.title('Interest rate vs Sub Grade')
plt.show()

# %% [markdown]
# From above graph, We can see that applicant with sub grade 'G4' and 'G5' has much higher interest rate compared to rest and then too the defaulter rate is much lower than 'F5'. Therefore, we can say that if the sub-grade of any applicant is 'F5' then we have to view their application more cautiously as they can be a potential defaulter.

# %% [markdown]
# ##### Analysis on Employee title with Loan Status

# %%
print('There are', data['emp_title'].nunique(), 'unique values in Employee title column')
# Out:
# There are 26850 unique values in Employee title column

# %% [markdown]
# It is difficult to plot graph with 26850 categorical values, so it would be better to take into account the top 20 titles.

# %%
# Pre processing the data to plot the graph
data_1 = data[['emp_title','loan_status']].value_counts().unstack()
data_1 = data_1.fillna(0)
data_1['sum'] = data_1.sum(axis=1)
data_1 = data_1.sort_values(by = 'sum',ascending = False)
data_1 = data_1.head(21)
data_1.drop('sum',axis = 1,inplace =True)

# %%
data_1.plot(kind = 'bar',stacked = True)
plt.xlabel("Employee Title")
plt.ylabel("Frequency")
plt.title("Analysis of Employee Title with Loan Status")
plt.show()

# %% [markdown]
# We can see that 'Unknown' employee title are more and it is biased towards 'Unknown' which is not feasible. It is better to analyse without it.

# %%
data_1 = data_1.iloc[1:,:]
data_1_perc = data_1.apply(lambda x : x/x.sum(),axis=1)

figure, (ax1,ax2) = plt.subplots(1, 2,figsize = (10,5))

data_1.plot(kind = 'bar',stacked = True,ax = ax1)
data_1_perc.plot(kind = 'bar',stacked = True,ax = ax2)
plt.show()

# %% [markdown]
# From the above graph, we can see that applicants having employee_title as walmart are defaulted more often then others. But this observation is not ethical as we cannot target a specific company due to some defaulter applicants.
#
# **Note** - We would suggest that we should add a column according to the type of companies like applicant is working in public or private sectors rather than its title.

# %% [markdown]
# ##### Analysis on Employee Length and Loan Status

# %%
# Pre processing the data to plot the graph
data_1 = data[['emp_length','loan_status']].value_counts().unstack()
data_1 = data_1.fillna(0)
data_1['sum'] = data_1.sum(axis=1)
data_1 = data_1.sort_values(by = 'sum',ascending = False)
data_1.drop('sum',axis = 1,inplace =True)
data_1_perc = data_1.apply(lambda x : x/x.sum(),axis=1)

# %%
figure, (ax1,ax2) = plt.subplots(1, 2,figsize = (10,5))

data_1.plot(kind = 'bar',stacked = True,ax = ax1)
data_1_perc.plot(kind = 'bar',stacked = True,ax = ax2)
plt.show()

# %% [markdown]
# From above graphs, we can see that employee having more than 10 years are applying for loan more often than others. Also it has very low percent of defaulter compared to other groups. As we can see that when the data related to employee length - 'Unknown', there is more chance of applicant to be defaulter.

# %% [markdown]
# ##### Analysis on dti

# %%
sns.boxplot(data['loan_status'],data['dti'])
plt.xlabel('Loan status')
plt.title('dti vs Loan status')
plt.show()

# %% [markdown]
# From graph, we can say that dti of charged-off applicant is higher than fully paid applicant. So if any applicant whose dti is high we have to screen their application further more while giving the loan. **It could be a good driving variable.**

# %% [markdown]
# #####  According to Delinquency

# %%
# preparing the data 
data_dq = data[['delinq_2yrs','loan_status']].value_counts().unstack()
data_dq_perc = data_dq.apply(lambda x: x/x.sum(),axis = 1)
fig , (ax1,ax2) = plt.subplots(1,2,figsize = (15,5))
data_dq.plot(kind='bar',stacked = True,ax = ax1)
data_dq_perc.plot(kind='bar',stacked = True,ax= ax2)
plt.show()

# %% [markdown]
# From above graphs, we can see that as the delinquency is increasing the default rate is also increaseing.
# But with delinquency 9 and 11 there are no defaulter which is not a good interpreter. It is due to lack of data.
# Beacuse of lack of data regarding delinquency more than 4 we cannot conclude anything on the same.

# %% [markdown]
# ##### According to Inquires in last 6months

# %%
# preparing the data 
data_inq = data[['inq_last_6mths','loan_status']].value_counts().unstack()
data_inq_perc = data_inq.apply(lambda x: x/x.sum(),axis = 1)
fig , (ax1,ax2) = plt.subplots(1,2,figsize = (15,5))
data_inq.plot(kind='bar',stacked = True,ax = ax1)
data_inq_perc.plot(kind='bar',stacked = True,ax= ax2)
plt.show()

# %% [markdown]
# From graph, we can see that as the inquiry done by applicant increases, the defaulter rate is also increasing.Reason behind it would be that previously the applicant wouldn't have fullfiled the criteria by company because of that applicant is inquiring it again. **It could be a good driving variable.**

# %% [markdown]
# ##### According to public records

# %%
# preparing the data 
data_pub = data[['pub_rec','loan_status']].value_counts().unstack()
data_pub_perc = data_pub.apply(lambda x: x/x.sum(),axis = 1)
fig , (ax1,ax2) = plt.subplots(1,2,figsize = (15,5))
data_pub.plot(kind='bar',stacked = True,ax = ax1)
data_pub_perc.plot(kind='bar',stacked = True,ax= ax2)
plt.show()
print(data_pub)
# Out:
# loan_status  Charged Off  Fully Paid
# pub_rec
# 0                 4959.0     29676.0
# 1                  449.0      1516.0
# 2                   10.0        36.0
# 3                    NaN         6.0
# 4                    NaN         2.0

# %% [markdown]
# From above graph, we can see that as the no. of derogatory records are increasing the defaulter rate is also increasing. We can see that public record having more 3 are not being defaulter but that is not the case. It is due to lack of data for public records for more than 3.

# %% [markdown]
# ##### According to Revolving balance.

# %%
# plotting the graph
fig,(ax1,ax2) = plt.subplots(1,2,figsize= (12,5))

# Plottng regarding the sum
sns.barplot(data['loan_status'],data['revol_bal'],estimator = np.sum,ax = ax1)
ax1.set_xlabel('Loan Status')
ax1.set_ylabel('Revolving Balance')
ax1.set_title('Loan status vs Revoling Balance(sum)')

# Plotting regarding the average
sns.barplot(data['loan_status'],data['revol_bal'],estimator = np.mean,ax = ax2)
ax2.set_xlabel('Loan Status')
ax2.set_ylabel('Revolving Balance')
ax2.set_title('Loan status vs Revoling Balance(average)')
plt.show()

# %% [markdown]
# From 1st graph, we can see that total revolving balance is more for fully paid applicant and it is due to the distribution of data.
# But when we plot the same graph with average as estimator, we get the clear picture that if the revolving balance is more, then the applicant can be defaulter. **It could be a good driving variable.**

# %% [markdown]
# ##### According to Revolving line utilization rate

# %%
# plotting the graph
fig,(ax1,ax2) = plt.subplots(1,2,figsize= (12,5))

# Plottng boxplot
sns.boxplot(data['loan_status'],data['revol_util'],ax = ax1)
ax1.set_xlabel('Loan Status')
ax1.set_ylabel('Revolving line utilization rate')
ax1.set_title('Loan status vs Revoling line utilization(box)')

# Plotting bar graph(mean)
sns.barplot(data['loan_status'],data['revol_util'],estimator = np.mean,ax = ax2)
ax2.set_xlabel('Loan Status')
ax2.set_ylabel('Revolving line utilization rate')
ax2.set_title('Loan status vs Revoling line utilization(bar)')
plt.show()

# %% [markdown]
# From graph, We can see that if revolving utilization rate is more than 50% than the possibility of applicant to be a defaulter is high. This can be a **good indicator** for applicant to be defaulter or not.

# %% [markdown]
# ##### Analysis on state

# %%
plt.figure(figsize= (24,8))
sns.countplot(data['addr_state'],hue = data['loan_status'])
plt.xlabel('States')
plt.ylabel('Frequency')
plt.title('State Distribution')
plt.show()

# %% [markdown]
# From graph, we can say that the mostly loan taken by the applicant who is living in 'CA' but we cannot conclude that from some data about their possibilty of becoming a defaulter or not. Because it is unethical and wrong, to conclude any applicant according to their states.

# %% [markdown]
# As we can see that most of bivariate analysis are useful but if we add much more variables to the analysis then there is a chance to get more insights which will gives us the confidence to finalize the driver variables.

# %% [markdown]
# ### Multi-variate Analysis

# %% [markdown]
# ##### Annual Income vs Loan Amount vs Loan Status

# %%
# Grouping the data to get better understanding of data. 
# we cannot take mean for grouping data because if we take mean, it will increase as annual income increase. 
# As we know as the income increases the amount of loan required will also increase.  
data_1 = data.groupby(['Annual Income Slab','loan_status'])['loan_amnt'].sum().unstack()
data_1.columns
data_1.plot(kind = 'bar',stacked = True,figsize=(12,8))
plt.ylabel("Total Loan Amount")
plt.show()

# %% [markdown]
# From above graph, we can see that mostly loan is taken by the employees whose annual income is from 25k to 75k and it is right skewed.And also we can also see in univariate analysis of income that most of the loan taken was by the applicant whose salary was from 25k to 50k. But we can't clearly see that how much percentage of people have repaid the loan or not.

# %%
# calculating the percentage of the data to get better understanding
data_1_perc = data_1.apply(lambda x:  x/x.sum(),axis = 1)
data_1_perc.plot(kind = 'bar',stacked = True,figsize=(12,8))
plt.show()

# %% [markdown]
# From above graph,we can see a trend that as the annual income is increasing, the possibility of applicant being defaulter is getting lesser and lesser. **It will be a good driving variable.**

# %% [markdown]
# ##### Analysis on Verification Status

# %%
# Pre processing for the data
data_1 = data[['emp_length','verification_status','loan_amnt','loan_status','annual_inc']]
data_1 = pd.pivot_table(data=data_1,values= ['loan_amnt','annual_inc'],index = ['verification_status'],columns= ['loan_status'],aggfunc = np.sum)

# %%
figure, (ax1,ax2) = plt.subplots(1, 2,figsize = (10,5))
data_1['annual_inc'].plot(kind='bar',stacked=True,ax = ax1)
ax1.set_xlabel('Annual Income')
ax1.set_title('Relative to Annual Income')

data_1['loan_amnt'].plot(kind = 'bar',stacked = True,ax = ax2)
ax2.set_xlabel('Loan Amaount')
ax2.set_title('Relative to Loan amount')
plt.show()

# %% [markdown]
# From above graph, we are not able to conclude any results.So, it is better to check with their proportion to get insights.

# %%
data_inc = data_1['annual_inc'].apply(lambda x: x/x.sum(),axis = 1)
data_lAmnt = data_1['loan_amnt'].apply(lambda x: x/x.sum(),axis =1)
figure, (ax1,ax2) = plt.subplots(1, 2,figsize = (10,5))
data_inc.plot(kind='bar',stacked=True,ax = ax1)
ax1.set_xlabel('Annual Income')
ax1.set_title('Relative to Annual Income')

data_lAmnt.plot(kind = 'bar',stacked = True,ax = ax2)
ax2.set_xlabel('Loan Amaount')
ax2.set_title('Relative to Loan amount')
plt.show()

# %% [markdown]
# From above graph, we can see that applicant is more prone to become a defaulter when their income source is verified.

# %% [markdown]
# ##### Analysis on Ownership of house and Purpose of Loan

# %%
data_ = data[['home_ownership','loan_amnt','loan_status','purpose']]

data_1 = pd.pivot_table(data=data_,values= ['loan_amnt'],index = ['home_ownership'],columns= ['loan_status'],aggfunc = np.sum)
data_2 = pd.pivot_table(data=data_,values= ['loan_amnt'],index = ['purpose'],columns= ['loan_status'],aggfunc = np.sum)

# %%
figure, (ax1,ax2) = plt.subplots(1, 2,figsize = (10,5))
data_1['loan_amnt'].plot(kind='bar',stacked=True,ax = ax1)
ax1.set_xlabel('Home Ownership')
ax1.set_title('Relative to Home Ownwership')

data_2['loan_amnt'].plot(kind = 'bar',stacked = True,ax = ax2)
ax2.set_xlabel('Purpose')
ax2.set_title('Relative to Purpose')
plt.show()

# %% [markdown]
# From the above graph, we can see that applicant having their property in mortgage are taking more loan amount than others.
#
# From second graph we can see that applicant are taking more loans for debt consolidation than others.
#
# We can understand more insights if we check with the proportion of data.

# %%
data_1_perc = data_1.apply(lambda x: x/x.sum(),axis=1)
data_2_perc = data_2.apply(lambda x: x/x.sum(),axis=1)

figure, (ax1,ax2) = plt.subplots(1, 2,figsize = (10,5))
data_1_perc['loan_amnt'].plot(kind='bar',stacked=True,ax = ax1)
ax1.set_xlabel('Home Ownership')
ax1.set_title('Relative to Home Ownwership')

data_2_perc['loan_amnt'].plot(kind = 'bar',stacked = True,ax = ax2)
ax2.set_xlabel('Purpose')
ax2.set_title('Relative to Purpose')
plt.show()

# %% [markdown]
# From graph, we can see that Home Ownership is not showing any significant variation with respect to loan status.
#
# From second graph, we can see that applicant taking the loan for small_business are less in amount but it is defaulted more often than others.
# We can say that if some one is applying for loan and he/she is stating that they are taking the loan for small business, then we should be more cautious while giving the loan.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We have done Data cleaning and Exploratory data analysis to get better insights of data. We found following driving variable which will give us inference about the applicant can be default or not.
#
# Following are the driving variables -
#    * **Grade** - We have seen that as the grade is lower then the chance of applicant to be defaulter increases.
#    * **Annual Income** - We have seen that as the annual income is increasing, the chances of applicant being a defaulter decreases.
#    * **Revolving Balance** -  We have seen that if the revolving balance is higher then the chance of applicant being defaulter is also high.
#    * **Loan Amount** - We have seen that as the loan amount increases, the possibility of applicant being defaulter also increases.
#    * **Revolving line utilization rate** - we have seen that if revolving line utilization rate is higher then there is a  higher chance of applicant being a defaulter.
#    * **DTI** - We have seen that higher the dti, higher is the chance of applicant being defaulter.
#    * **Interest Rate** - We have seen that as the interest rate increases, then the possibility of applicant being defaulter also increases.
#    * **Inquiry in last 6months** - We have seen that if the no. of inquires is more, then defaulter rate is also high.
#
#
# Hence, we have analyzed the **Lending Club Case Study** with the help of various data cleaning and EDA methods.
